# %% [markdown]
# # IMPORTING THE DATASET

# %%
import pandas as pd
df=pd.read_csv('baseball.csv')
print (df)
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# 30 ROWS AND 17 COLUMNS

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # CHECKING NULL VALUES

# %%
import numpy as np
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Mean and median values are slight different
#
# max defines maximum values of different columns
#
# min defines minimum values of different columns

# %% [markdown]
# # CHECKING CORELLATION OF DIFFERENT VARIABLES

# %%
import matplotlib as plt
import seaborn as sns
sns.heatmap(df.corr(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")

# %% [markdown]
# graph is not clear so applying corr function

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# from the table we observe that RA,ER,ERA,SV vlues strongly correlated with target variable

# %% [markdown]
# # CHECKING SKEWNESS

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# data is less skewd so we are not removing skewness

# %% [markdown]
# # SPLITTING INO X AND Y

# %%
x=df.drop("W",axis=1)
y=df["W"]
x.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %% [markdown]
# # CHECKING OUTLIERS

# %%
import seaborn as sns
import matplotlib as plt
x.iloc[:,0:9].boxplot(figsize=[30,10])
plt.subplot_adjust(bottom=0.25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-dee5065a412c> in <module>
#       2 import matplotlib as plt
#       3 x.iloc[:,0:9].boxplot(figsize=[30,10])
# ----> 4 plt.subplot_adjust(bottom=0.25)
#       5 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'subplot_adjust'

# %% [markdown]
# graph is not clear so checking individually

# %%
df['R'].plot.box()

# %%
df['RA'].plot.box()

# %%
df['SHO'].plot.box()

# %%
df['SB'].plot.box()

# %%
df['CG'].plot.box()

# %%
# some columns has outliers so outliers have to be romoved

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_z=df[(z<3).all(axis=1)]

# %%
df_z
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_z.shape
# Out:
# (29, 17)

# %% [markdown]
# # SCALING THE DATA

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
scaled = mms.fit_transform(df_z)
print(scaled)
# Out:
# [[0.86486486 0.79057592 0.71969697 0.90575916 0.95522388 0.80555556
#   0.3        0.04166667 0.         0.66666667 0.36363636 0.38317757
#   0.37619048 0.18181818 0.23529412 0.82352941 0.25490196]
#  [0.54054054 0.64397906 0.31060606 0.13089005 0.6119403  0.86111111
#   0.43076923 0.33333333 0.53394495 0.28888889 0.54858934 0.54517134
#   0.53809524 0.18181818 0.47058824 0.5        0.21568627]
#  [0.48648649 0.5026178  0.20454545 0.37172775 1.         0.44444444
#   0.31538462 0.82291667 0.33761468 0.46666667 0.36050157 0.33021807
#   0.34761905 1.         0.35294118 0.29411765 0.07843137]
#  [0.35135135 0.2565445  0.56060606 0.29842932 0.35820896 0.38888889
#   0.27692308 0.15104167 0.4733945  0.26666667 0.55172414 0.51401869
#   0.4952381  0.63636364 0.29411765 0.26470588 0.50980392]
#  [0.2972973  0.60732984 0.83333333 1.         0.79104478 1.
#   0.39230769 0.41666667 0.52477064 0.43333333 0.87147335 0.83489097
#   0.80952381 0.63636364 0.47058824 0.20588235 0.21568627]
# ...

# %% [markdown]
# # CHOOSING BEST RANDOM STATE

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

for i in range(0,100):
    x_train, x_test,y_train,y_test = train_test_split(x, y, test_size=0.33, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state {i} the training accuracy is:-{r2_score (y_train,pred_train)}")
    print(f"at random state {i} the testing accuracy is:-{r2_score (y_test,pred_test)}")
    print("\n")
# Out:
# at random state 0 the training accuracy is:-0.9731879174118999
# at random state 0 the testing accuracy is:-0.4712270464471595
#
#
# at random state 1 the training accuracy is:-0.9861554940658502
# at random state 1 the testing accuracy is:-0.23938516757809325
#
#
# at random state 2 the training accuracy is:-0.9949487541766617
# at random state 2 the testing accuracy is:--1.403453142894807
#
#
# at random state 3 the training accuracy is:-0.9841322813947121
# at random state 3 the testing accuracy is:-0.019659586657633454
#
#
# at random state 4 the training accuracy is:-0.9638605932295414
# at random state 4 the testing accuracy is:-0.6960104895589541
#
#
# at random state 5 the training accuracy is:-0.9639439374607679
# at random state 5 the testing accuracy is:-0.440312049855235
#
#
# at random state 6 the training accuracy is:-0.9561677392474612
# at random state 6 the testing accuracy is:-0.6743364926917699
#
#
# at random state 7 the training accuracy is:-0.9735872931856179
# ...

# %% [markdown]
# SPLITTING INTO TRAINING AND TESTING

# %%
x_train, x_test,y_train,y_test = train_test_split(x, y, test_size=0.33, random_state=13)

# %% [markdown]
# APPLYING LINEAR REGRESSION

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)
print(r2_score (y_test,pred_test))
# Out:
# 0.8070769634991793

# %% [markdown]
# REGULARIZING:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':(range(0,10))}
ls= Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.941742235263516, tolerance: 0.1898
#   positive)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.93509540373862, tolerance: 0.1405
#   positive)
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.9688377349130555, tolerance: 0.18609375
#   positive)
# ...

# %%
ls = Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)
lss = r2_score(y_test,pred_ls)
lss
# Out:
# 0.7554975578453312

# %% [markdown]
# ENSEMBLING:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
rf = RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rf = rf.predict(x_test)
rfs = r2_score(y_test,pred_rf)
print('R2 Score:', rfs*100)
rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 38.19079604633862
# Cross Val Score: -81.38360758178835

# %% [markdown]
# We are getting the model accuracy 80% in linear regression so choosing linear regression as best model
